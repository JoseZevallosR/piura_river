# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Q_filled_output_relu.csv')

# %%
df['Q_filled'].plot(figsize = (15,10))
plt.show()

# %%
df.describe()
# Out:
#                  Q             P      Q_interp      Q_filled
# count  9780.000000  12783.000000  12783.000000  10362.000000
# mean     37.740406      3.014404     30.760129     35.620649
# std     103.241540      2.434729     91.626090    100.675722
# min       0.000000      0.006379      0.000000      0.000000
# 25%       0.000000      1.245241      0.000000      0.000000
# 50%       0.300000      2.380319      0.000000      0.100000
# 75%      22.000000      4.146524     16.200000     18.000000
# max    2165.000000     25.413019   2165.000000   2165.000000
